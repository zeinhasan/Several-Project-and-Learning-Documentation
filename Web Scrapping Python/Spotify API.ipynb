# %% [markdown]
# # Library

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import pandas as pd
import re
import numpy as np

# %% [markdown]
# # Authenticator

# %%
cid="91c6987695df4ee0808a8543b6338ce5"
secret="ee1cf985cb7b4b1098588c11f89f6402"

# %% [markdown]
# # Requests

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# # Get Data

# %%
playlist_link = "https://open.spotify.com/playlist/1EVE9kOZ2i4171hNdvWVhU?si=2c78eb109a5f4e53"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
track_uris
# Out:
# ['spotify:track:4LRPiXqCikLlN15c3yImP7',
#  'spotify:track:0WtM2NBVQNNJLh6scP13H8',
#  'spotify:track:1k6r6F3hdLtWvNjVZdlRHw',
#  'spotify:track:0mBP9X2gPCuapvpZ7TGDk3',
#  'spotify:track:4nrPB8O7Y7wsOCJdgXkthe',
#  'spotify:track:5YbPxJwPfrj7uswNwoF1pJ',
#  'spotify:track:0yLdNVWF3Srea0uzk55zFn',
#  'spotify:track:0oWraSo5ASJ0h1BEagTyEw',
#  'spotify:track:2IQg4g8vZfNr5AlZnkNqb4',
#  'spotify:track:0gYXw7aPoybWFfB7btQ0eM',
#  'spotify:track:0HqZX76SFLDz2aW8aiqi7G',
#  'spotify:track:62wwF30E7FQvmd9AiZFvvd',
#  'spotify:track:0QBzMgT7NIeoCYy3sJCof1',
#  'spotify:track:6tCd8bPvYnceDG7W9M1RMk',
#  'spotify:track:3nqQXoyQOWXiESFLlDF1hG',
#  'spotify:track:1BSMpVGWs3v5BZKnAQziAc',
#  'spotify:track:4h9wh7iOZ0GGn8QVp4RAOB',
#  'spotify:track:73vIOb4Q7YN6HeJTbscRx5',
#  'spotify:track:4uUG5RXrOk84mYEfFvj3cK',
#  'spotify:track:6HMtHNpW6YPi1hrw9tgF8P',
#  'spotify:track:0V3wPSX9ygBnCm8psDIegu',
#  'spotify:track:0QHEIqNKsMoOY5urbzN48u',
#  'spotify:track:0hquQWY3xvYqN4qtiquniF',
#  'spotify:track:3LtpKP5abr2qqjunvjlX5i',
#  'spotify:track:59nOXPmaKlBfGMDeOVGrIK',
#  'spotify:track:6VhuP99TE6gYNQRJIlAWFD',
#  'spotify:track:6xGruZOHLs39ZbVccQTuPZ',
#  'spotify:track:0HaRLPnr887lcQM2YQzkff',
#  'spotify:track:1rDQ4oMwGJI7B4tovsBOxc',
#  'spotify:track:35ovElsgyAtQwYPYnZJECg',
#  'spotify:track:2SLwbpExuoBDZBpjfefCtV',
#  'spotify:track:0O6u0VJ46W86TxN9wgyqDj',
#  'spotify:track:3smlpsXoDcTvDqHZTYfJLe',
#  'spotify:track:5CM4UuQ9Gnd6K2YyKGPMoK',
#  'spotify:track:0TyUOnU4H4GLqOcrH0auc8',
#  'spotify:track:6dGqGkYDoRrKh5UiIcTT22',
#  'spotify:track:7mFj0LlWtEJaEigguaWqYh',
#  'spotify:track:0QPRDC97rIQB3Jh3hrVJoH',
#  'spotify:track:4cGqn0E8JCSY9gQllQj4Mf',
#  'spotify:track:1nH2PkJL1XoUq8oE6tBZoU',
#  'spotify:track:0skYUMpS0AcbpjcGsAbRGj',
#  'spotify:track:1qEmFfgcLObUfQm0j1W2CK',
#  'spotify:track:2KnLkZ3z7PO3kgVGHGqDpD',
#  'spotify:track:7DwcBgdzqhFJltEaV1XF81',
#  'spotify:track:2X9DiwKcqchzUqQh8TvKcH',
#  'spotify:track:59CfNbkERJ3NoTXDvoURjj',
#  'spotify:track:5S9Zs5g9lTWnLIboN1pdlU']

# %%
len(track_uris)
# Out:
# 100

# %%
playlist_track_uri = []
playlist_track_name = []
playlist_artist_uri = []
playlist_artist_info = []
playlist_artist_popularity = []
playlist_artist_genre = []
playlist_album = []
playlist_track_popularity = []
playlist_artist_name= []
playlist_track_id= []

# %%
for track in sp.playlist_tracks(playlist_URI)["items"]:
    # ID
    track_id = track['track']['id']
    playlist_track_id.append(track_id)

    #URI
    track_uri = track["track"]["uri"]
    playlist_track_uri.append(track_uri)

    #Track name
    track_name = track["track"]["name"]
    playlist_track_name.append(track_name)

    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    playlist_artist_uri.append(artist_uri)
    artist_info = sp.artist(artist_uri)
    playlist_artist_info.append(artist_info)
    
    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    playlist_artist_name.append(artist_name)
    artist_pop = artist_info["popularity"]
    playlist_artist_popularity.append(artist_info)
    artist_genres = artist_info["genres"]
    playlist_artist_genre.append(artist_genres)
    
    #Album
    album = track["track"]["album"]["name"]
    playlist_album.append(album)

    #Popularity of the track
    track_pop = track["track"]["popularity"]
    playlist_track_popularity.append(track_pop)

# %% [markdown]
# # Extract

# %%
data_mentah = sp.audio_features(playlist_track_id)

# %%
data = pd.DataFrame(data=data_mentah,columns=data_mentah[0].keys())

# %%
data.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.520   0.731    6    -5.338     0       0.0557         0.342
# 1         0.801   0.806   11    -5.206     1       0.0381         0.382
# 2         0.619   0.458    7    -7.880     1       0.0251         0.547
# 3         0.881   0.592    2    -4.898     1       0.0324         0.619
# 4         0.778   0.632    2    -5.600     0       0.0493         0.274
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.001010    0.3110    0.662  173.930  audio_features
# 1          0.000669    0.1140    0.802  106.999  audio_features
# 2          0.000000    0.1370    0.391  135.914  audio_features
# 3          0.000013    0.0901    0.719  101.058  audio_features
# 4          0.000000    0.0915    0.498  122.104  audio_features
#
#                        id                                   uri  \
# 0  4LRPiXqCikLlN15c3yImP7  spotify:track:4LRPiXqCikLlN15c3yImP7
# 1  0WtM2NBVQNNJLh6scP13H8  spotify:track:0WtM2NBVQNNJLh6scP13H8
# 2  1k6r6F3hdLtWvNjVZdlRHw  spotify:track:1k6r6F3hdLtWvNjVZdlRHw
# 3  0mBP9X2gPCuapvpZ7TGDk3  spotify:track:0mBP9X2gPCuapvpZ7TGDk3
# 4  4nrPB8O7Y7wsOCJdgXkthe  spotify:track:4nrPB8O7Y7wsOCJdgXkthe
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4LRPiXqCikLl...
# 1  https://api.spotify.com/v1/tracks/0WtM2NBVQNNJ...
# 2  https://api.spotify.com/v1/tracks/1k6r6F3hdLtW...
# 3  https://api.spotify.com/v1/tracks/0mBP9X2gPCua...
# 4  https://api.spotify.com/v1/tracks/4nrPB8O7Y7ws...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4LRP...       167303
# 1  https://api.spotify.com/v1/audio-analysis/0WtM...       239318
# 2  https://api.spotify.com/v1/audio-analysis/1k6r...       168840
# 3  https://api.spotify.com/v1/audio-analysis/0mBP...       154487
# 4  https://api.spotify.com/v1/audio-analysis/4nrP...       218289
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
data['track_name']=playlist_track_name 
data['artist_uri']=playlist_artist_uri 
data['genre']=playlist_artist_genre
data['track_popularity']=playlist_track_popularity
data['artist_name']=playlist_artist_name

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      100 non-null    float64
#  1   energy            100 non-null    float64
#  2   key               100 non-null    int64
#  3   loudness          100 non-null    float64
#  4   mode              100 non-null    int64
#  5   speechiness       100 non-null    float64
#  6   acousticness      100 non-null    float64
#  7   instrumentalness  100 non-null    float64
#  8   liveness          100 non-null    float64
#  9   valence           100 non-null    float64
#  10  tempo             100 non-null    float64
#  11  type              100 non-null    object
#  12  id                100 non-null    object
#  13  uri               100 non-null    object
#  14  track_href        100 non-null    object
#  15  analysis_url      100 non-null    object
#  16  duration_ms       100 non-null    int64
#  17  time_signature    100 non-null    int64
#  18  track_name        100 non-null    object
#  19  artist_uri        100 non-null    object
#  20  genre             100 non-null    object
#  21  track_popularity  100 non-null    int64
#  22  artist_name       100 non-null    object
# dtypes: float64(9), int64(5), object(9)
# memory usage: 18.1+ KB

# %% [markdown]
# # Cleaning

# %%
data['uri']=data['uri'].str.replace('spotify:track:','')
data['artist_uri']=data['artist_uri'].str.replace('spotify:artist:','')
data['genre']=data['genre'].astype('str')
data['genre']=data['genre'].str.replace("]", "")
data['genre']=data['genre'].str.replace("[", "")
# Out:
# C:\Users\hasan\AppData\Local\Temp\ipykernel_25252\2211314782.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['genre']=data['genre'].str.replace("]", "")
# C:\Users\hasan\AppData\Local\Temp\ipykernel_25252\2211314782.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['genre']=data['genre'].str.replace("[", "")

# %%
data=data.drop(columns='type',axis=1)

# %%
data.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.520   0.731    6    -5.338     0       0.0557         0.342
# 1         0.801   0.806   11    -5.206     1       0.0381         0.382
# 2         0.619   0.458    7    -7.880     1       0.0251         0.547
# 3         0.881   0.592    2    -4.898     1       0.0324         0.619
# 4         0.778   0.632    2    -5.600     0       0.0493         0.274
#
#    instrumentalness  liveness  valence  ...                     uri  \
# 0          0.001010    0.3110    0.662  ...  4LRPiXqCikLlN15c3yImP7
# 1          0.000669    0.1140    0.802  ...  0WtM2NBVQNNJLh6scP13H8
# 2          0.000000    0.1370    0.391  ...  1k6r6F3hdLtWvNjVZdlRHw
# 3          0.000013    0.0901    0.719  ...  0mBP9X2gPCuapvpZ7TGDk3
# 4          0.000000    0.0915    0.498  ...  4nrPB8O7Y7wsOCJdgXkthe
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4LRPiXqCikLl...
# 1  https://api.spotify.com/v1/tracks/0WtM2NBVQNNJ...
# 2  https://api.spotify.com/v1/tracks/1k6r6F3hdLtW...
# 3  https://api.spotify.com/v1/tracks/0mBP9X2gPCua...
# 4  https://api.spotify.com/v1/tracks/4nrPB8O7Y7ws...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4LRP...      167303
# 1  https://api.spotify.com/v1/audio-analysis/0WtM...      239318
# 2  https://api.spotify.com/v1/audio-analysis/1k6r...      168840
# 3  https://api.spotify.com/v1/audio-analysis/0mBP...      154487
# 4  https://api.spotify.com/v1/audio-analysis/4nrP...      218289
#
#   time_signature                               track_name  \
# 0              4                                As It Was
# 1              4            Calm Down (with Selena Gomez)
# 2              4                             Song for You
# 3              4  Left and Right (Feat. Jung Kook of BTS)
# 4              4    Shakira: Bzrp Music Sessions, Vol. 53
#
#                artist_uri                                              genre  \
# 0  6KImCVD70vtIoJWnq6nGn3                                              'pop'
# 1  46pWGuE3dSwY3bMMXGBvVS                                     'nigerian pop'
# 2  6cfxwqUKYLqwqVu9X3wv6v
# 3  6VuMaDnrHyPL1p4EHjYLi7                    'dance pop', 'pop', 'viral pop'
# 4  716NhGYqD1jl2wI1Qkgq36  'argentine hip hop', 'pop venezolano', 'trap a...
#
#   track_popularity   artist_name
# 0               89  Harry Styles
# 1               92          Rema
# 2               35    Lee Isaacs
# 3               81  Charlie Puth
# 4               96      Bizarrap
#
# [5 rows x 22 columns]

# %% [markdown]
# # Export

# %%
data.to_excel('100 Popular Song 2022.xlsx')
