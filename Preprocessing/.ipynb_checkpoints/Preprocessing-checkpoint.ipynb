# %%
import pandas as pd
import numpy as np
import scipy.stats

# %% [markdown]
# ### Import Data

# %%
train = pd.read_csv('Dataset Andaat_Data Latih.csv')
test = pd.read_csv('Dataset Andaat_Data Uji.csv')

# %%
train
# Out:
#       Rating  ...         Android Ver
# 0        5.0  ...          4.0 and up
# 1        4.8  ...          3.0 and up
# 2        4.8  ...          4.0 and up
# 3        4.8  ...          4.1 and up
# 4        4.8  ...          4.1 and up
# ...      ...  ...                 ...
# 9565     3.7  ...          2.3 and up
# 9566     3.6  ...          4.4 and up
# 9567     3.5  ...  Varies with device
# 9568     3.5  ...          5.0 and up
# 9569     3.3  ...          4.1 and up
#
# [9570 rows x 11 columns]

# %% [markdown]
# ### Drop Duplicates

# %%
train=train.drop_duplicates()

# %% [markdown]
# ### Ubah Kategori dan Standardisasi

# %%
frames = [train,test]
gabung = pd.concat(frames)

# %%
gabung.head()
# Out:
#    Rating  ... Android Ver
# 0     5.0  ...  4.0 and up
# 1     4.8  ...  3.0 and up
# 2     4.8  ...  4.0 and up
# 3     4.8  ...  4.1 and up
# 4     4.8  ...  4.1 and up
#
# [5 rows x 11 columns]

# %% [markdown]
# Ubah Kategori Android Version

# %%
gabung['Android Ver'].value_counts()
# Out:
# 4.1 and up            2379
# 4.0.3 and up          1458
# 4.0 and up            1338
# Varies with device    1221
# 4.4 and up             893
# 2.3 and up             643
# 5.0 and up             546
# 4.2 and up             387
# 2.3.3 and up           279
# 2.2 and up             239
# 3.0 and up             237
# 4.3 and up             235
# 2.1 and up             133
# 1.6 and up             116
# 6.0 and up              58
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              22
# 1.5 and up              20
# 4.4W and up             11
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 5.0 - 8.0                2
# 4.0.3 - 7.1.1            2
# 1.0 and up               2
# 5.0 - 7.1.1              1
# 7.0 - 7.1.1              1
# 5.0 - 6.0                1
# 4.1 - 7.1.1              1
# 2.2 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
gabung['Android Ver'][gabung['Android Ver']=='4.4W and up']='4.4 and up'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
gabung.loc[gabung['Android Ver'].isin((gabung['Android Ver'].value_counts()[gabung['Android Ver'].value_counts() < 50]).index), 'Android Ver'] = 'other'

# %%
gabung['Android Ver'].value_counts()
# Out:
# 4.1 and up            2379
# 4.0.3 and up          1458
# 4.0 and up            1338
# Varies with device    1221
# 4.4 and up             904
# 2.3 and up             643
# 5.0 and up             546
# 4.2 and up             387
# 2.3.3 and up           279
# 2.2 and up             239
# 3.0 and up             237
# 4.3 and up             235
# other                  189
# 2.1 and up             133
# 1.6 and up             116
# 6.0 and up              58
# Name: Android Ver, dtype: int64

# %% [markdown]
# Ubah Kategori Content Rating

# %%
gabung['Content Rating'].value_counts()
# Out:
# Everyone           8387
# Teen               1146
# Mature 17+          449
# Everyone 10+        377
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
gabung['Content Rating'][gabung['Content Rating']=='Everyone 10+']='Everyone'
gabung['Content Rating'][gabung['Content Rating']=='Unrated']='Everyone'
gabung['Content Rating'][gabung['Content Rating']=='Adults only 18+']='Mature 17+'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
gabung['Content Rating'].value_counts()
# Out:
# Everyone      8766
# Teen          1146
# Mature 17+     452
# Name: Content Rating, dtype: int64

# %% [markdown]
# Isi NaN type

# %%
gabung['Type'].value_counts()
# Out:
# Free    9597
# Paid     766
# Name: Type, dtype: int64

# %%
gabung['Type'][gabung['Type'].isna()==True]='Free'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
gabung['Type'].value_counts()
# Out:
# Free    9598
# Paid     766
# Name: Type, dtype: int64

# %% [markdown]
# Bikin dummy kategori

# %%
dms = pd.get_dummies(gabung[['Category']])
dms.head()
# Out:
#    Category_ART_AND_DESIGN  ...  Category_WEATHER
# 0                        1  ...                 0
# 1                        1  ...                 0
# 2                        1  ...                 0
# 3                        1  ...                 0
# 4                        1  ...                 0
#
# [5 rows x 33 columns]

# %%
gabung= pd.concat([gabung,dms], axis=1 )
gabung
# Out:
#       Rating  ... Category_WEATHER
# 0        5.0  ...                0
# 1        4.8  ...                0
# 2        4.8  ...                0
# 3        4.8  ...                0
# 4        4.8  ...                0
# ...      ...  ...              ...
# 1265     NaN  ...                0
# 1266     NaN  ...                0
# 1267     NaN  ...                0
# 1268     NaN  ...                0
# 1269     NaN  ...                0
#
# [10364 rows x 44 columns]

# %%
gabung = gabung.drop(['Category'],axis=1)

# %%
dms = pd.get_dummies(gabung[['Type']])
gabung= pd.concat([gabung,dms], axis=1 )
gabung = gabung.drop(['Type'],axis=1)

# %%
dms = pd.get_dummies(gabung[['Content Rating']])
gabung= pd.concat([gabung,dms], axis=1 )
gabung = gabung.drop(['Content Rating'],axis=1)

# %%
gabung=gabung.drop(['Genres'],axis=1)

# %%
dms = pd.get_dummies(gabung[['Android Ver']])
gabung= pd.concat([gabung,dms], axis=1 )
gabung = gabung.drop(['Android Ver'],axis=1)

# %%
gabung
# Out:
#       Rating  ... Android Ver_other
# 0        5.0  ...                 0
# 1        4.8  ...                 0
# 2        4.8  ...                 0
# 3        4.8  ...                 0
# 4        4.8  ...                 0
# ...      ...  ...               ...
# 1265     NaN  ...                 0
# 1266     NaN  ...                 0
# 1267     NaN  ...                 0
# 1268     NaN  ...                 0
# 1269     NaN  ...                 0
#
# [10364 rows x 60 columns]

# %%
gabung['coba'] = gabung['Size'].str.strip().str[-1]

# %%
dms = pd.get_dummies(gabung[['Installs']])
gabung= pd.concat([gabung,dms], axis=1 )
gabung = gabung.drop(['Installs'],axis=1)

# %%
gabung['Size'][gabung['coba']=='k']='< 1 Mb'
gabung['Size'][(gabung['coba']=='M')]='> 1 Mb'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
gabung=gabung.drop(['coba'],axis=1)

# %%
dms = pd.get_dummies(gabung[['Size']])
gabung= pd.concat([gabung,dms], axis=1 )
gabung = gabung.drop(['Size'],axis=1)

# %%
gabung['Price']=gabung.Price.str.extract('(\d.\d*)')

# %%
gabung
# Out:
#       Rating  ... Size_Varies with device
# 0        5.0  ...                       0
# 1        4.8  ...                       0
# 2        4.8  ...                       0
# 3        4.8  ...                       0
# 4        4.8  ...                       0
# ...      ...  ...                     ...
# 1265     NaN  ...                       0
# 1266     NaN  ...                       0
# 1267     NaN  ...                       0
# 1268     NaN  ...                       0
# 1269     NaN  ...                       0
#
# [10364 rows x 82 columns]

# %% [markdown]
# Isi NaN Price pake 0

# %%
gabung['Price'] = gabung['Price'].fillna('0')

# %%
train_pre = gabung.iloc[0:9093]
test_pre = gabung.iloc[9094:10364]

# %% [markdown]
# Drop NA in rating

# %%
train_pre.isna().sum()
# Out:
# Rating                     204
# App                          0
# Reviews                      0
# Price                        0
# Category_ART_AND_DESIGN      0
#                           ...
# Installs_500,000+            0
# Installs_500,000,000+        0
# Size_< 1 Mb                  0
# Size_> 1 Mb                  0
# Size_Varies with device      0
# Length: 82, dtype: int64

# %%
train_pre=train_pre.dropna()

# %% [markdown]
# standardisasi

# %%
train_pre
# Out:
#       Rating  ... Size_Varies with device
# 0        5.0  ...                       0
# 1        4.8  ...                       0
# 2        4.8  ...                       0
# 3        4.8  ...                       0
# 4        4.8  ...                       0
# ...      ...  ...                     ...
# 9564     3.7  ...                       1
# 9565     3.7  ...                       0
# 9566     3.6  ...                       0
# 9567     3.5  ...                       1
# 9568     3.5  ...                       0
#
# [8889 rows x 82 columns]

# %%
num=['Reviews','Price','Rating']

# %%
from sklearn.preprocessing import RobustScaler
sc = RobustScaler()
train_pre[num] = sc.fit_transform(train_pre[num])
test_pre[num] = sc.transform(test_pre[num])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %% [markdown]
# ### Hapus Outlier Price

# %%
#hapus Outlier
q3 = train_pre.Price.quantile(0.75)
batas = q3 + 1.5*(q3 - train_pre.Price.quantile(0.25))
train_pre = train_pre[~(train_pre['Price']>=batas)]

# %% [markdown]
# ### Jadiin X y yeay

# %%
X_trainn = train_pre.drop(['Rating','App'],axis=1)
y_trainn = train_pre.Rating
X_test = test_pre.drop(['Rating','App'], axis=1)
y_test = test_pre.Rating

# %%
X_test
# Out:
#        Reviews  Price  ...  Size_> 1 Mb  Size_Varies with device
# 0    -0.065385   0.00  ...            1                        0
# 1    -0.063683   0.00  ...            1                        0
# 2    -0.064569   0.00  ...            1                        0
# 3    -0.057045   0.00  ...            1                        0
# 4    -0.065160   0.00  ...            1                        0
# ...        ...    ...  ...          ...                      ...
# 1265 -0.066229   0.00  ...            1                        0
# 1266 -0.066243   0.00  ...            1                        0
# 1267 -0.066229   1.99  ...            1                        0
# 1268 -0.066243   0.00  ...            1                        0
# 1269 -0.066243   0.00  ...            1                        0
#
# [1270 rows x 80 columns]
