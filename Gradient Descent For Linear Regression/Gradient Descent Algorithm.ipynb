# %% [markdown]
# # Teori Awal

# %%
xi = 1 #nilai x awal atau x0 
alpha = 0.001 # konstanta pembelajaran 
maksimal_iterasi = 100000 
target_error = 0.0001 # kondisi berhenti/error

# %%
# Turunan
def derivative(x): 
  return 2*x+1

# %%
# Iterasi 
for iterasi in range (1,maksimal_iterasi+1): 
  x_current = xi 
  xi = xi - alpha * derivative(xi) 
  error = abs(xi - x_current) 
  print(f"Epoch: {iterasi}\t" f" x: {x_current:.4f}\terror {error:.4f}") 
  if error < target_error: break
# Out:
# Epoch: 1	 x: 1.0000	error 0.0030
# Epoch: 2	 x: 0.9970	error 0.0030
# Epoch: 3	 x: 0.9940	error 0.0030
# Epoch: 4	 x: 0.9910	error 0.0030
# Epoch: 5	 x: 0.9880	error 0.0030
# Epoch: 6	 x: 0.9851	error 0.0030
# Epoch: 7	 x: 0.9821	error 0.0030
# Epoch: 8	 x: 0.9791	error 0.0030
# Epoch: 9	 x: 0.9762	error 0.0030
# Epoch: 10	 x: 0.9732	error 0.0029
# Epoch: 11	 x: 0.9703	error 0.0029
# Epoch: 12	 x: 0.9673	error 0.0029
# Epoch: 13	 x: 0.9644	error 0.0029
# Epoch: 14	 x: 0.9615	error 0.0029
# Epoch: 15	 x: 0.9585	error 0.0029
# Epoch: 16	 x: 0.9556	error 0.0029
# Epoch: 17	 x: 0.9527	error 0.0029
# Epoch: 18	 x: 0.9498	error 0.0029
# Epoch: 19	 x: 0.9469	error 0.0029
# Epoch: 20	 x: 0.9440	error 0.0029
# Epoch: 21	 x: 0.9411	error 0.0029
# Epoch: 22	 x: 0.9382	error 0.0029
# Epoch: 23	 x: 0.9354	error 0.0029
# Epoch: 24	 x: 0.9325	error 0.0029
# Epoch: 25	 x: 0.9296	error 0.0029
# Epoch: 26	 x: 0.9268	error 0.0029
# Epoch: 27	 x: 0.9239	error 0.0028
# Epoch: 28	 x: 0.9211	error 0.0028
# ...

# %% [markdown]
# # Studi Kasus

# %%
# Library
from numpy import *

# %%
# Fungsi Menghitung Error
def compute_error(b, m, points):
    totalError = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        totalError += (y - (m * x + b)) ** 2
    return totalError / float(len(points))

# %%
# Fungsi Menghitung Step Gradient
def step_gradient(b_current, m_current, points, learningRate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_b, new_m]

# %%
# fungsi menghitung gradient descent
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
    return [b, m]

# %%
# fungsi menjalankan algoritma
def run():
    points = df.values
    learning_rate = 0.0001
    initial_b = 0
    initial_m = 0
    num_iterations = 100000
    print ("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error(initial_b, initial_m, points)))
    print ("Running...")
    [b,m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print(b)
    print(m)
    print ("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error(b, m, points)))

# %%
# Baca datanya
import pandas as pd
df = pd.read_csv('Data.csv',header=None)

# %%
df
# Out:
#             0          1
# 0   32.502345  31.707006
# 1   53.426804  68.777596
# 2   61.530358  62.562382
# 3   47.475640  71.546632
# 4   59.813208  87.230925
# ..        ...        ...
# 95  50.030174  81.536991
# 96  49.239765  72.111832
# 97  50.039576  85.232007
# 98  48.149859  66.224958
# 99  25.128485  53.454394
#
# [100 rows x 2 columns]

# %%
run()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# 4.247984440219195
# 1.3959992655297513
# After 100000 iterations b = 4.247984440219195, m = 1.3959992655297513, error = 110.78631929745085
